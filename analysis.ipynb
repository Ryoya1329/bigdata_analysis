# %%
import pandas as pd
import numpy as np
import pulp
import matplotlib.pyplot as plt

# %%
# バス時刻表の最適化
# 最適化問題の定義
prob = pulp.LpProblem('bus', pulp.LpMinimize)
# 集合の定義
# 右回りバスの、バス停の集合
Right_BusStop = ['つくばセンター(行き)', '吾妻小学校(行き)', '筑波大学春日エリア前(行き)', '筑波メディカルセンター前(行き)', '筑波大学病院入口', '追越学生宿舎前', '平砂学生宿舎前', '筑波大学西', '大学会館前', '第一エリア前', 
                 '第三エリア前', '虹の広場前', '農林技術センター', '一ノ矢学生宿舎前', '大学植物見本園', '第二エリア前', 'TARAセンター前', '筑波大学中央', '大学公園', '松美池', 
                 '天久保三丁目', '合宿所', '天久保池', '天久保二丁目', '追越宿舎東', 'メディカルセンター病院', '筑波メディカルセンター前(帰り)', '筑波大学春日エリア前(帰り)', '吾妻小学校(帰り)', 'つくばセンター(帰り)']
# 左回りバスの、バス停の集合
Left_BusStop = ['つくばセンター(行き)', '吾妻小学校(行き)', '筑波大学春日エリア前(行き)', '筑波メディカルセンター前(行き)', 'メディカルセンター病院', '追越宿舎東', '天久保二丁目', '天久保池', '合宿所', '天久保三丁目', 
                '松美池', '大学公園', '筑波大学中央', 'TARAセンター前', '第二エリア前', '大学植物見本園', '一ノ矢学生宿舎前', '農林技術センター', '虹の広場前', '第三エリア前', 
                '第一エリア前', '大学会館前', '筑波大学西', '平砂学生宿舎前', '追越学生宿舎前', '筑波大学病院入口', '筑波メディカルセンター前(帰り)', '筑波大学春日エリア前(帰り)', '吾妻小学校(帰り)', 'つくばセンター(帰り)']
# 時刻の集合
Time = list(range(60*24))
# 右回りバスが前のバス停から次のバス停に到着するまでの時間の集合
Right_ArriveTime = [0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 
                    3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
                    3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 左回りバスが前のバス停から次のバス停に到着するまでの時間の集合
Left_ArriveTime = [0, 3, 3, 3, 3, 3, 3, 3, 3, 3, 
                   3, 3, 3, 3, 3, 3, 3, 3, 3, 3,
                   3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# 右回りバスの、各バス停で乗車の需要が高まると予想される時刻の集合
Right_InTime = {Right_BusStop[0]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[1]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[2]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[3]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[4]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[5]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[6]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[7]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[8]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[9]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[10]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[11]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[12]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[13]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[14]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[15]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[16]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[17]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[18]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[19]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[20]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[21]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[22]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[23]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[24]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[25]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[26]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[27]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[28]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Right_BusStop[29]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,]}
# 左回りバスの、各バス停で乗車の需要が高まると予想される時刻の集合
Left_InTime = {Left_BusStop[0]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[1]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[2]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[3]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[4]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[5]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[6]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[7]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[8]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[9]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[10]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[11]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[12]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[13]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[14]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[15]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[16]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[17]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[18]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[19]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[20]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[21]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[22]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[23]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[24]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[25]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[26]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[27]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[28]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,],
                Left_BusStop[29]: [0, 30, 60, 90, 120, 150, 180, 210, 240, 270,]}

# 定数の定義
# バス会社の始業時間
Start_Time = 6*60
# バス会社の終業時間
End_Time = 23*60
#1日の右回りバスの本数
Right_BusNum = 10
# Out:
# 1440
